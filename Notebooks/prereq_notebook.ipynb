# %% [markdown]
# Hi, my name it Tamera but I go by Tammy. I have about 25 years of experience in IT support. I am excited to learn about data analysis. I think it will be fun and very advantages.

# %%
print("I have successfully run a line of code!")
# Out:
# I have successfully run a line of code!
